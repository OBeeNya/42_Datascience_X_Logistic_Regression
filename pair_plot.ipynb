# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/dataset_train.csv')
df['Left hand'] = np.multiply(df['Best Hand'] == 'Left', 1)
df.drop(['Index', 'First Name', 'Last Name', 'Birthday', 'Astronomy', 'Best Hand', 'Care of Magical Creatures'],
		axis=1,
		inplace=True)

# %%
sns.pairplot(df, hue='Hogwarts House');

# %% [markdown]
# Ancient Runes, Herbology, Defense Against the Dark Arts
